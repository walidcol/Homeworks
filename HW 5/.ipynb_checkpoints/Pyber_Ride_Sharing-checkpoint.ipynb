# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# %%
# File to Load (Remember to change these)

# city data
city_data = "C:/Users/Walid/Documents/Columbia/COLNYC20190716DATA/02-Homeworks/05-Matplotlib/Instructions/Pyber/data/city_data.csv"

city_df = pd.read_csv(city_data)
city_df.head()
# Out:
#            city  driver_count   type
# 0   Richardfort            38  Urban
# 1  Williamsstad            59  Urban
# 2   Port Angela            67  Urban
# 3    Rodneyfort            34  Urban
# 4   West Robert            39  Urban

# %%
# ride data

ride_data = "C:/Users/Walid/Documents/Columbia/COLNYC20190716DATA/02-Homeworks/05-Matplotlib/Instructions/Pyber/data/ride_data.csv"
ride_df = pd.read_csv(ride_data)
ride_df.head()
# Out:
#                  city                 date   fare        ride_id
# 0  Lake Jonathanshire  2018-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2018-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2018-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2018-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2018-03-06 04:28:35  34.58  3908451377344

# %%
# Combine the data into a single dataset

cityride = pd.merge(city_df, ride_df, how = "left", on = "city")
cityride.head()
# Out:
#           city  driver_count   type                 date   fare        ride_id
# 0  Richardfort            38  Urban  2018-02-24 08:40:38  13.93  5628545007794
# 1  Richardfort            38  Urban  2018-02-13 12:46:07  14.00   910050116494
# 2  Richardfort            38  Urban  2018-02-16 13:52:19  17.92   820639054416
# 3  Richardfort            38  Urban  2018-02-01 20:18:28  10.26  9554935945413
# 4  Richardfort            38  Urban  2018-04-17 02:26:37  23.00   720020655850

# %%
# Obtain the x and y coordinates for each of the three city types

group_cityride = cityride.groupby(["city"] +["type"] + ["driver_count"])
group_cityride.head()
# Out:
#                    city  driver_count   type                 date   fare  \
# 0           Richardfort            38  Urban  2018-02-24 08:40:38  13.93
# 1           Richardfort            38  Urban  2018-02-13 12:46:07  14.00
# 2           Richardfort            38  Urban  2018-02-16 13:52:19  17.92
# 3           Richardfort            38  Urban  2018-02-01 20:18:28  10.26
# 4           Richardfort            38  Urban  2018-04-17 02:26:37  23.00
# 28         Williamsstad            59  Urban  2018-01-23 17:51:24  19.62
# 29         Williamsstad            59  Urban  2018-03-29 21:43:04  35.58
# 30         Williamsstad            59  Urban  2018-02-13 20:07:49  33.72
# 31         Williamsstad            59  Urban  2018-05-01 01:26:21  26.81
# 32         Williamsstad            59  Urban  2018-02-23 17:42:40   4.68
# 51          Port Angela            67  Urban  2018-04-17 06:23:18  16.34
# 52          Port Angela            67  Urban  2018-03-31 15:22:26  30.77
# ...

# %%
# Average fare Per City

avg_fare = group_cityride["fare"].mean()

#Total Number of Rides Per City

total_ride = group_cityride["driver_count"].count()

df = pd.DataFrame({"Average Fare" : avg_fare, 
                   "Total Ride" : total_ride })
df.head()
# Out:
#                                      Average Fare  Total Ride
# city          type     driver_count
# Amandaburgh   Urban    12               24.641667          18
# Barajasview   Urban    26               25.332273          22
# Barronchester Suburban 11               36.422500          16
# Bethanyland   Suburban 22               32.956111          18
# Bradshawfurt  Rural    7                40.064000          10

# %%
# Build the scatter plots for each city types
# create legends

#a = mpatches.Circle((0.5, 0.5), 0.1, facecolor="lightcoral",alpha=.6,edgecolor="black",)
#b = mpatches.Circle((0.5, 0.5), 0.1, facecolor="lightskyblue",alpha=.6,edgecolor="black")
#c = mpatches.Circle((0.5, 0.5), 0.1, facecolor="gold",alpha=.6,edgecolor="black")

plt.scatter(avg_fare, total_ride, marker="o", facecolors="red", edgecolors="black")


# Set x and y limits
ax.set_xlim(0, max(df['Total Ride'])+2)
ax.set_ylim(15, max(df['Average Fare'])+1)


plt.legend([a,b,c],["Urban","Suburban","Rural"],title= 'City Type')
plt.title("Pyber Ride Sharing Data")
plt.xlabel("Total Number of Rides Per City)")
plt.ylabel("Average Fare")

plt.show()

# %%
# calculate variables that will be used in the Pie Chart
df1 = cityride.groupby(['type'])
df2 = city_df.groupby(['type'])

# Calculate Total fare($) Per CityType
TFare = df1['fare'].sum()

# Calculate Total Rides Per CityType
TRides = df1['ride_id'].count()

# Calculate Total Drivers Per CityType
TDrivers = df2['driver_count'].sum()

df3 = pd.DataFrame({"TotalFare":TFare, "TotalRides":TRides, "TotalDrivers":TDrivers})
df3 =  df3.reset_index()
df3
# Out:
#        type  TotalFare  TotalRides  TotalDrivers
# 0     Rural    4327.93         125            78
# 1  Suburban   19356.33         625           490
# 2     Urban   39854.38        1625          2405

# %%
# Total Fares by City Type

labels = df3["type"]
sizes = df3['TotalFare']
colors = ["gold", "lightskyblue", "lightcoral"]
plt.figure(figsize=(9,5))
plt.pie(sizes, colors=colors, labels = labels, 
            autopct="%1.1f%%", shadow=True, startangle=100)

plt.title("Total Fares by City Type")
# Prints our pie chart to the screen
plt.show()

# %%
# Total ride by city type

labels = df3["type"]
sizes = df3['TotalRides']
colors = ["gold", "lightskyblue", "lightcoral"]
plt.figure(figsize=(9,5))
plt.pie(sizes, colors=colors, labels = labels, 
            autopct="%1.1f%%", shadow=True, startangle=100)

plt.title("Total Fares by City Type")
# Prints our pie chart to the screen
plt.show()

# %%
# Total drivers by city type

labels = df3["type"]
sizes = df3['TotalDrivers']
colors = ["gold", "lightskyblue", "lightcoral"]
plt.figure(figsize=(9,5))
plt.pie(sizes, colors=colors, labels = labels, 
            autopct="%1.1f%%", shadow=True, startangle=100)

plt.title("Total Fares by City Type")
# Prints our pie chart to the screen
plt.show()
